# %%
import csv
ticker = []
with open('part1.csv') as tic:
    rows = csv.reader(tic)
    for row in rows:
        #ticker.append(row[0])
        print(row)
# Out:
# ['QTRH']
# ['CHFS']
# ['GTHX']
# ['NESRU']
# ['NESRW']
# ['SSTI']
# ['ATXI']
# ['CPTAG']
# ['IMRN']
# ['IMRNW']
# ['MOTAW']
# ['MOTA']
# ['SLNOW']
# ['NVUS']
# ['APPN']
# ['CELH']
# ['KBLMU']
# ['CPTAL']
# ['RILYZ']
# ['AFHBL']
# ['YLDE']
# ['CSML']
# ['LRGE']
# ['ARGX']
# ['SLNO']
# ['SGH']
# ['GNTY']
# ['NDRAU']
# ['FMAO']
# ['ACCPW']
# ['UONEK']
# ['UONE']
# ['NESRU']
# ['CACG']
# ['ALT']
# ['ASV']
# ['VERI']
# ['MPAC']
# ['MPACW']
# ['SRUN']
# ['SRUNW']
# ['FMCIW']
# ['FMCIR']
# ['USOI']
# ['FMCI']
# ['VEACW']
# ['URGN']
# ['VEAC']
# ['OVID']
# ['ROSE']
# ['ROSEW']
# ['SVRA']
# ['CATS']
# ['KAAC']
# ['KAACW']
# ['ROSEU']
# ['CFBI']
# ['NDRA']
# ['NDRAW']
# ['LINU']
# ['PLXP']
# ['VSDA']
# ['TICCL']
# ['PCSB']
# ['VRNA']
# ['NCSM']
# ['SSNT']
# ['YERR']
# ['MIIIW']
# ['IMED']
# ['HUNT']
# ['CERCW']
# ['SCACU']
# ['OCC']
# ['INTG']
# ['DTUL']
# ['MIIIU']
# ['FTEO']
# ['BMRA']
# ['PSET']
# ['CETC']
# ['FTW']
# ['STLRW']
# ['OACQR']
# ['EACQ']
# ['DFVS']
# ['FKO']
# ['IRCP']
# ...
